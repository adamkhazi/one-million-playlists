# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os
sys.path.append(os.path.abspath('../'))
from api import API
from data import Data
import pandas as pd

# %%
a = API()
p = a.getFeaturedPlaylists()

# %%
p
# Out:
# {'message': 'Almost weekend',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?timestamp=2018-07-27T14%3A51%3A56&offset=0&limit=50',
#   'items': [{'collaborative': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify/playlist/37i9dQZF1DWXJfnUiYjUKT'},
#     'href': 'https://api.spotify.com/v1/users/spotify/playlists/37i9dQZF1DWXJfnUiYjUKT',
#     'id': '37i9dQZF1DWXJfnUiYjUKT',
#     'images': [{'height': 300,
#       'url': 'https://i.scdn.co/image/bafb0dba7553ab262a65f50568ede005c884bf97',
#       'width': 300}],
#     'name': 'New Music Friday',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
# ...

# %%
editorialPlaylist = a.getPlaylist('37i9dQZF1DWXJfnUiYjUKT')

# %%
editorialPlaylist['tracks']['items'][0]['track']['uri']
# Out:
# 'spotify:track:6e2PtJYcltVk76nLwxBzRn'

# %%
pTracks = a.getPlaylist('37i9dQZF1DXadOVCgGhS7j')

# %%
pTracks['tracks']
# Out:
# {'href': 'https://api.spotify.com/v1/users/spotify/playlists/37i9dQZF1DXadOVCgGhS7j/tracks?offset=0&limit=100',
#  'items': [{'added_at': '2018-07-02T11:45:20Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3rWZHrfrsPBxVy692yAIxF'},
#        'href': 'https://api.spotify.com/v1/artists/3rWZHrfrsPBxVy692yAIxF',
#        'id': '3rWZHrfrsPBxVy692yAIxF',
#        'name': 'Willow',
#        'type': 'artist',
#        'uri': 'spotify:artist:3rWZHrfrsPBxVy692yAIxF'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4cJGBartFvMddvZpAaUHf6'},
# ...

# %%
for i in p['playlists']['items']:
    print(i['name'], i['id'])
# Out:
# New Music Friday 37i9dQZF1DWXJfnUiYjUKT
# Happy Hits! 37i9dQZF1DXdPec7aLTmlC
# Baila Reggaeton 37i9dQZF1DWY7IeIP1cdjF
# A Perfect Day 37i9dQZF1DWSXBu5naYCM9
# Get Turnt 37i9dQZF1DWY4xHQp97fN6
# Brain Food 37i9dQZF1DWXLeA8Omikj7
# Today's Top Hits 37i9dQZF1DXcBWIGoYBM5M
# Peaceful Piano 37i9dQZF1DX4sWSpwq3LiO
# Mellow Beats 37i9dQZF1DX3qCx5yEZkcJ
# Your Office Stereo 37i9dQZF1DX31KQt69Gaqf
# Guilty Pleasures 37i9dQZF1DX4pUKG1kS0Ac
# Summer Throwbacks 37i9dQZF1DWZg863fGtALu

# %%
a.getPlaylist('37i9dQZF1DXcBWIGoYBM5M')
# Out:
# {'collaborative': False,
#  'description': 'Benny Blanco, Halsey and Khalid make it to the top of the Hottest 50.',
#  'external_urls': {'spotify': 'https://open.spotify.com/user/spotify/playlist/37i9dQZF1DXcBWIGoYBM5M'},
#  'followers': {'href': None, 'total': 20927616},
#  'href': 'https://api.spotify.com/v1/users/spotify/playlists/37i9dQZF1DXcBWIGoYBM5M',
#  'id': '37i9dQZF1DXcBWIGoYBM5M',
#  'images': [{'height': 300,
#    'url': 'https://i.scdn.co/image/cf943576fc1f9c061cb514f3a016df5c606f01c7',
#    'width': 300}],
#  'name': "Today's Top Hits",
#  'owner': {'display_name': 'Spotify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#   'href': 'https://api.spotify.com/v1/users/spotify',
#   'id': 'spotify',
#   'type': 'user',
#   'uri': 'spotify:user:spotify'},
#  'primary_color': '#C3F0C8',
#  'public': True,
#  'snapshot_id': 'MTUzMjY5MjE1MSwwMDAwMDIyODAwMDAwMTY0ZGIxZTYyMjAwMDAwMDE2NGRiMWQ3Yzk2',
# ...

# %%
data = Data()

# %%
data.downloadedEditorialPlaylists()
# Out:
# retrying ...1secs

# %%
data.downloadedSpecificEditorialPlaylist('37i9dQZF1DXadOVCgGhS7j')
