# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %load_ext line_profiler

# %%
import sys
import os
sys.path.append(os.path.abspath('../'))
from api import API
from data import Data
from mongo_to_sql import MongoToSql
import pandas as pd

pd.set_option('display.max_columns', 150)

# %%
m = MongoToSql()

# %%
m.moveUGTrackFeatures()
# Out:
# 0it [00:00, ?it/s]
# 102it [00:00, 198.79it/s]
# 667it [00:00, 1087.95it/s]
# 1254it [00:00, 1756.20it/s]
# 1836it [00:00, 2249.97it/s]
# 2420it [00:00, 2641.98it/s]
# 2968it [00:01, 2915.79it/s]
# 3539it [00:01, 3165.87it/s]
# 4112it [00:01, 3370.97it/s]
# 4685it [00:01, 3551.64it/s]
# 5268it [00:01, 3712.27it/s]
# 5846it [00:01, 3845.94it/s]
# 6406it [00:01, 3953.34it/s]
# 7001it [00:01, 4064.75it/s]
# 7568it [00:01, 4146.76it/s]
# 8146it [00:01, 4231.66it/s]
# 8727it [00:02, 4306.95it/s]
# 9313it [00:02, 4380.06it/s]
# 9894it [00:02, 4442.36it/s]
# 10468it [00:02, 4493.55it/s]
# 11040it [00:02, 4540.26it/s]
# 11609it [00:02, 4585.52it/s]
# 12184it [00:02, 4630.27it/s]
# 12770it [00:02, 4672.27it/s]
# 13346it [00:02, 4710.72it/s]
# 13919it [00:02, 4726.19it/s]
# 14475it [00:03, 4750.96it/s]
# 15055it [00:03, 4783.98it/s]
# 15644it [00:03, 4816.61it/s]
# 16229it [00:03, 4844.63it/s]
# 16814it [00:03, 4873.82it/s]
# 17388it [00:03, 4894.13it/s]
# 17959it [00:03, 4912.47it/s]
# ...
